# %%
import tensorflow as tf
from tensorflow import keras 

tf.__version__
# Out:
# '2.2.0'

# %%
resnet101 = tf.keras.applications.ResNet101(include_top=False, input_shape=(320, 320, 3), weights=None)

# %%
resnet101.summary()
# Out:
# Model: "resnet101"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 326, 326, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 160, 160, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 160, 160, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 160, 160, 64) 0           conv1_bn[0][0]
# ...

# %%
resnetv2 = tf.keras.applications.ResNet101V2(include_top=False, input_shape=(513, 513, 3), weights=None)

# %%
resnetv2.summary()
# Out:
# Model: "resnet101v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 513, 513, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 519, 519, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 257, 257, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 259, 259, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 129, 129, 64) 0           pool1_pad[0][0]
# ...

# %%
from tensorflow.keras import layers

# %%
resnetTop = tf.keras.applications.ResNet101(include_top=True)
resnetTop.summary()
# Out:
# ...
# 179650560/179648224 [==============================] - 7s 0us/step
# Model: "resnet101"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
resnet101_321 = tf.keras.applications.ResNet101(include_top=False, input_shape=(321, 321, 3), weights=None)
resnet101_321.summary()
# Out:
# Model: "resnet101"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_8 (InputLayer)            [(None, 321, 321, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 327, 327, 3)  0           input_8[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 161, 161, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 161, 161, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 161, 161, 64) 0           conv1_bn[0][0]
# ...

# %%
resnet101v2_321 = tf.keras.applications.ResNet101V2(include_top=False, input_shape=(320, 320, 3), weights=None)
resnet101v2_321.summary()
# Out:
# Model: "resnet101v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_25 (InputLayer)           [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 326, 326, 3)  0           input_25[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 160, 160, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 162, 162, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 80, 80, 64)   0           pool1_pad[0][0]
# ...

# %%
from tensorflow.keras import Sequential
from tensorflow.keras import layers


block5 = Sequential(layers=[
    layers.Conv2D(1024, 3, dilation_rate=6, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(1024, 1, dilation_rate=1, strides=1, padding='same', activation='relu'),
    layers.BatchNormalization(),
], name='block5')

# 6th block output shape: B, 512, 10, 10
block6 = Sequential(layers=[
    layers.Conv2D(256, 1, activation='relu', padding='same'),
    layers.Conv2D(512, 3, strides=2, padding='same', activation='relu'),
], name='block6')

# 7th block output shape: B, 256, 5, 5
block7 = Sequential(layers=[
    layers.Conv2D(128, 1, padding='same', activation='relu'),
    layers.Conv2D(256, 3, strides=2, padding='same', activation='relu'),
], name='block7')

# 8th block output shape: B, 256, 3, 3
block8 = Sequential(layers=[
    layers.Conv2D(128, 1, padding='same', activation='relu'),
    layers.Conv2D(256, 3, strides=2, padding='same', activation='relu'),
], name='block8')

# 9th block output shape: B, 256, 1, 1
block9 = Sequential(layers=[
    layers.Conv2D(128, 1, padding='same', activation='relu'),
    layers.Conv2D(256, 3, strides=2, padding='valid', activation='relu'),
], name='block9')

# # 10th block output shape: B, 256, 1, 1
# block10 = Sequential(layers=[
#     layers.Conv2D(128, 1, padding='same', activation='relu'),
#     layers.Conv2D(256, 4, padding='same', activation='relu'),], name='block10')

input = layers.Input(shape=[32, 32, 2048])
# input = layers.Input(shape=[19, 19, 1024])
x = block5(input)
x = block6(x)
x = block7(x)
x = block8(x)
x = block9(x)
# x = block10(x)

ssdOut = tf.keras.Model(input, x)
ssdOut.summary()
# Out:
# Model: "model_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_355 (InputLayer)       [(None, 32, 32, 2048)]    0
# _________________________________________________________________
# block5 (Sequential)          (None, 32, 32, 1024)      19933184
# _________________________________________________________________
# block6 (Sequential)          (None, 16, 16, 512)       1442560
# _________________________________________________________________
# block7 (Sequential)          (None, 8, 8, 256)         360832
# _________________________________________________________________
# block8 (Sequential)          (None, 4, 4, 256)         328064
# _________________________________________________________________
# block9 (Sequential)          (None, 1, 1, 256)         328064
# ...
# Total params: 22,392,704
# Trainable params: 22,388,608
# Non-trainable params: 4,096
# ...

# %%
input = layers.Input(shape=[5,5,256])
x = layers.Conv2D(128, 1, padding='same', activation='relu')(input)
x = layers.Conv2D(256, 3, strides=1, padding='valid', activation='relu')(x)
bl8 = tf.keras.Model(input, x)
bl8.summary()
# Out:
# Model: "functional_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_46 (InputLayer)        [(None, 5, 5, 256)]       0
# _________________________________________________________________
# conv2d_206 (Conv2D)          (None, 5, 5, 128)         32896
# _________________________________________________________________
# conv2d_207 (Conv2D)          (None, 3, 3, 256)         295168
# ...
# Total params: 328,064
# Trainable params: 328,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.layers import Conv2DTranspose, Input, BatchNormalization, Conv2D, Activation, Dense, GlobalAveragePooling2D, MaxPooling2D, ZeroPadding2D, Add
from tensorflow.keras.initializers import he_uniform

kernel_init = he_uniform()

def conv1_layer(x):    
    x = ZeroPadding2D(padding=(3, 3))(x)
    x = Conv2D(64, (7, 7), strides=(2, 2), kernel_initializer=kernel_init, bias_initializer='zeros')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = ZeroPadding2D(padding=(1,1))(x)
 
    return x   


def conv2_layer(x):         
    x = MaxPooling2D((3, 3), 2)(x)     
 
    shortcut = x
 
    for i in range(3):
        if (i == 0):
            x = Conv2D(64, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(shortcut)            
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut])
            x = Activation('relu')(x)
            
            shortcut = x
 
        else:
            x = Conv2D(64, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(64, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])   
            x = Activation('relu')(x)  
 
            shortcut = x        
    
    return x


def conv3_layer(x):        
    shortcut = x    
    
    for i in range(4):     
        if(i == 0):            
            x = Conv2D(128, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(512, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)    
 
            shortcut = x              
        
        else:
            x = Conv2D(128, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(128, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])     
            x = Activation('relu')(x)
 
            shortcut = x      
            
    return x


def conv4_layer(x):
    shortcut = x        
  
    for i in range(23):
        if(i == 0):            
            x = Conv2D(256, (1, 1), strides=(2, 2), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  
 
            x = Conv2D(1024, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(1024, (1, 1), strides=(2, 2), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)
 
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)
 
            shortcut = x               
        
        else:
            x = Conv2D(256, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(256, (3, 3), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(1024, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)            
 
            x = Add()([x, shortcut])    
            x = Activation('relu')(x)
 
            shortcut = x      
 
    return x


def conv5_layer(x):
    shortcut = x    
  
    for i in range(3):     
        if(i == 0):            
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)        
            
            x = Conv2D(512, (3, 3), dilation_rate=(2, 2), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)  

            x = Conv2D(2048, (1, 1), strides=(1, 1), padding='valid')(x)
            shortcut = Conv2D(2048, (1, 1), strides=(1, 1), padding='valid')(shortcut)
            x = BatchNormalization()(x)
            shortcut = BatchNormalization()(shortcut)            

            x = Add()([x, shortcut])  
            print('here')

            x = Activation('relu')(x)      
 
            shortcut = x               
        
        else:
            print('here')
            x = Conv2D(512, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
            
            x = Conv2D(512, (3, 3), dilation_rate=(2, 2), strides=(1, 1), padding='same')(x)
            x = BatchNormalization()(x)
            x = Activation('relu')(x)
 
            x = Conv2D(2048, (1, 1), strides=(1, 1), padding='valid')(x)
            x = BatchNormalization()(x)           
            
            x = Add()([x, shortcut]) 
            x = Activation('relu')(x)       
 
            shortcut = x                  
 
    return x

# %%
out = conv1_layer(Input(shape=[513, 513, 3]))
print(out)
# Out:
# Tensor("zero_padding2d_1/Identity:0", shape=(None, 259, 259, 64), dtype=float32)

# %%
pp = [1,2,3]
for i in range(len(pp), 0, -1):
    print(i)
# Out:
# 3
# 2
# 1

# %%
def create_resnet101_layers():
    input_layer = Input(shape=[320, 320, 3])
    out_layer = input_layer
    out_layer = conv1_layer(out_layer)
    out_layer = conv2_layer(out_layer)
    out_layer = conv3_layer(out_layer)
    
    resnet101_conv3 = tf.keras.Model(input_layer, out_layer)


    # input_layer = Input(shape=[None, None, 3])
    # out_layer = input_layer
    out_layer = conv4_layer(out_layer)
    out_layer = conv5_layer(out_layer)
    resnet101_conv5 = tf.keras.Model(input_layer, out_layer)

    return resnet101_conv3, resnet101_conv5

res3, res5 = create_resnet101_layers()
res3.summary()
# Out:
# here
# here
# here
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 326, 326, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 160, 160, 64) 9472        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 160, 160, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# ...

# %%
res5.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 320, 320, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 326, 326, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 160, 160, 64) 9472        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 160, 160, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from tensorflow.keras.layers import Multiply

# have to modify padding and strides
def from_before_layer(x, pad, ks):
    print('from_before_layer')
    print('1. ', x.get_shape().as_list())
    x = Conv2DTranspose(512, 2, strides=2, padding='same')(x)
    print('2. ', x.get_shape().as_list())
    x = Conv2D(512, 3, padding='same')(x)
    x = BatchNormalization()(x)
    print('3. ', x.get_shape().as_list(), '\n')

    return x


# have to modify padding and strides
def from_feature_layer(x):
    print('in from_feature_layer')
    print('1. ', x.get_shape().as_list())
    x = Conv2D(512, 3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    print('2. ', x.get_shape().as_list())
    
    x = Conv2D(512, 3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    print('3. ', x.get_shape().as_list())

    return x
  
def deconv_layer(from_before, from_feature):
    print('from_before : ', from_before.get_shape().as_list())
    print('from_feature : ', from_feature.get_shape().as_list())
    print()

    pad = 'valid' if from_before.get_shape().as_list()[1] != from_feature.get_shape().as_list()[1] else 'same'
    ks = 2 if pad == 'valid' else 3  
#     print(from_before.get_shape().as_list()[1], from_feature.get_shape().as_list()[1], pad, ks)

    fdl = from_before_layer(from_before, pad, ks)
    ffl = from_feature_layer(from_feature)

#     print(fdl.get_shape().as_list())
#     print(ffl.get_shape().as_list())
    print()

    x = Multiply()([fdl, ffl])
    x = Activation('relu')(x)

    print('last out : ', x.get_shape().as_list())

    return x
 
be = Input(shape=[10, 10, 512])
fe = Input(shape=[20, 20, 2048])

deconv_layer(be, fe)

# be = Input(shape=[3, 3, 256])
# fe = Input(shape=[5, 5, 256])

# deconv_layer(be, fe)
# Out:
# from_before :  [None, 10, 10, 512]
# from_feature :  [None, 20, 20, 2048]
#
# from_before_layer
# 1.  [None, 10, 10, 512]
# 2.  [None, 20, 20, 512]
# 3.  [None, 20, 20, 512]
#
# in from_feature_layer
# 1.  [None, 20, 20, 2048]
# 2.  [None, 20, 20, 512]
# 3.  [None, 20, 20, 512]
#
# last out :  [None, 20, 20, 512]
# <tf.Tensor 'activation_33/Identity:0' shape=(None, 20, 20, 512) dtype=float32>

# %%
# have to modify padding and strides
def from_before_layer(x, pad, ks):
    print('from_before_layer')
    print('1. ', x.get_shape().as_list())
    x = Conv2DTranspose(512, 2, strides=4, padding='same')(x)
    print('2. ', x.get_shape().as_list())
    x = Conv2D(512, 3, strides=1, padding='valid')(x)
    x = BatchNormalization()(x)
    print('3. ', x.get_shape().as_list(), '\n')

    return x


# have to modify padding and strides
def from_feature_layer(x):
    print('in from_feature_layer')
    print('1. ', x.get_shape().as_list())
    x = Conv2D(512, 3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    print('2. ', x.get_shape().as_list())
    
    x = Conv2D(512, 3, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    print('3. ', x.get_shape().as_list())

    return x


def deconv_layer(from_before, from_feature):
    print('from_before : ', from_before.get_shape().as_list())
    print('from_feature : ', from_feature.get_shape().as_list())
    print()

    pad = 'valid' if from_before.get_shape().as_list()[1] != from_feature.get_shape().as_list()[1] else 'same'
    ks = 2 if pad == 'valid' else 3  
#     print(from_before.get_shape().as_list()[1], from_feature.get_shape().as_list()[1], pad, ks)

    fdl = from_before_layer(from_before, pad, ks)
    ffl = from_feature_layer(from_feature)

#     print(fdl.get_shape().as_list())
#     print(ffl.get_shape().as_list())
    print()

    x = Multiply()([fdl, ffl])
    x = Activation('relu')(x)

    print('last out : ', x.get_shape().as_list())

    return x

# be = Input(shape=[10, 10, 512])
# fe = Input(shape=[20, 20, 2048])

# deconv_layer(be, fe)

be = Input(shape=[3, 3, 256])
fe = Input(shape=[5, 5, 256])

deconv_layer(be, fe)
# Out:
# from_before :  [None, 3, 3, 256]
# from_feature :  [None, 5, 5, 256]
#
# from_before_layer
# 1.  [None, 3, 3, 256]
# 2.  [None, 12, 12, 512]
# 3.  [None, 10, 10, 512]
#
# in from_feature_layer
# 1.  [None, 5, 5, 256]
# 2.  [None, 5, 5, 512]
# 3.  [None, 5, 5, 512]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-167-66d60e9ae34c> in <module>
#      59 fe = Input(shape=[5, 5, 256])
#      60
# ---> 61 deconv_layer(be, fe)
#
# <ipython-input-167-66d60e9ae34c> in deconv_layer(from_before, from_feature)
#      44     print()
#      45
# ---> 46     x = Multiply()([fdl, ffl])
#      47     x = Activation('relu')(x)
#      48
#
# ~/anaconda3/envs/tf2.2/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     895           # Build layer if applicable (if the `build` method has been
# ...

# %%
def deconv_ten(be, fe):
    print('from_before_layer')
    print('1. ', be.get_shape().as_list())
    be = Conv2DTranspose(512, 2, strides=2, padding='valid')(be)
    pad = 'valid' if be.get_shape().as_list()[1] != fe.get_shape().as_list()[1] else 'same'
    ks = 2 if pad == 'valid' else 3
    print('2. ', be.get_shape().as_list(), ks, pad)
    be = Conv2D(512, ks, padding=pad)(be)
    be = BatchNormalization()(be)
    print('3. ', be.get_shape().as_list(), '\n')
    
    
    print('in from_feature_layer')
    print('1. ', fe.get_shape().as_list())
    fe = Conv2D(512, 1, padding='same')(fe)
    fe = BatchNormalization()(fe)
    fe = Activation('relu')(fe)
    print('2. ', fe.get_shape().as_list())
    
    fe = Conv2D(512, 3, padding='same')(fe)
    fe = BatchNormalization()(fe)
    print('3. ', fe.get_shape().as_list())
    
    x = Multiply()([be, fe])
    x = Activation('relu')(x)

    print('last out : ', x.get_shape().as_list())

be = Input(shape=[1, 1, 256])
fe = Input(shape=[4, 4, 256])

be = Input(shape=[4, 4, 512])
fe = Input(shape=[8, 8, 256])

be = Input(shape=[8, 8, 512])
fe = Input(shape=[16, 16, 512])

be = Input(shape=[16, 16, 512])
fe = Input(shape=[32, 32, 1024])

be = Input(shape=[32, 32, 1024])
fe = Input(shape=[64, 64, 512])

deconv_ten(be, fe)
# Out:
# from_before_layer
# 1.  [None, 32, 32, 1024]
# 2.  [None, 64, 64, 512] 3 same
# 3.  [None, 64, 64, 512]
#
# in from_feature_layer
# 1.  [None, 64, 64, 512]
# 2.  [None, 64, 64, 512]
# 3.  [None, 64, 64, 512]
# last out :  [None, 64, 64, 512]

# %%
be = Input(shape=[1, 1, 256])
fe = Input(shape=[3, 3, 256])

be = Input(shape=[3, 3, 512])
fe = Input(shape=[5, 5, 256])

be = Input(shape=[5, 5, 512])
fe = Input(shape=[10, 10, 512])

be = Input(shape=[10, 10, 512])
fe = Input(shape=[20, 20, 1024])

be = Input(shape=[20, 20, 1024])
fe = Input(shape=[40, 40, 2048])

deconv_ten(be, fe)
# Out:
# from_before_layer
# 1.  [None, 20, 20, 1024]
# 2.  [None, 40, 40, 512] 3 same
# 3.  [None, 40, 40, 512]
#
# in from_feature_layer
# 1.  [None, 40, 40, 2048]
# 2.  [None, 40, 40, 512]
# 3.  [None, 40, 40, 512]
# last out :  [None, 40, 40, 512]

# %%
def prediction_layer(x):
    shortcut = x
    
    x = Conv2D(256, 1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(256, 1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(1024, 1, strides=1, padding='same')(x)

    shortcut = Conv2D(1024, 1, strides=1, padding='same')(shortcut)
    shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)

    return x

pr1 = prediction_layer(Input(shape=[1, 1, 256]))
pr2 = prediction_layer(Input(shape=[4, 4, 512]))
pr3 = prediction_layer(Input(shape=[8, 8, 512]))
pr4 = prediction_layer(Input(shape=[16, 16, 512]))
pr5 = prediction_layer(Input(shape=[32, 32, 512]))
pr6 = prediction_layer(Input(shape=[64, 64, 512]))

# %%
pr1.shape
# Out:
# TensorShape([None, 1, 1, 1024])

# %%
pr2.shape
# Out:
# TensorShape([None, 4, 4, 1024])

# %%
pr3.shape
# Out:
# TensorShape([None, 8, 8, 1024])

# %%
pr4.shape
# Out:
# TensorShape([None, 16, 16, 1024])

# %%
pr5.shape
# Out:
# TensorShape([None, 32, 32, 1024])

# %%
pr6.shape
# Out:
# TensorShape([None, 64, 64, 1024])

# %%
anchors = [4, 6, 6, 6, 4, 4, 4]
num_classes = 7

conf_head_layers = [
    Conv2D(anchors[0] * num_classes, kernel_size=3, padding='same'),  # for 4th block
    Conv2D(anchors[1] * num_classes, kernel_size=3, padding='same'),  # for 7th block
    Conv2D(anchors[2] * num_classes, kernel_size=3, padding='same'),  # for 8th block
    Conv2D(anchors[3] * num_classes, kernel_size=3, padding='same'),  # for 9th block
    Conv2D(anchors[4] * num_classes, kernel_size=3, padding='same'),  # for 10th block
    Conv2D(anchors[5] * num_classes, kernel_size=3, padding='same'),  # for 11th block
    Conv2D(anchors[6] * num_classes, kernel_size=1)  # for 12th block
]

loc_head_layers = [
    Conv2D(anchors[0] * 4, kernel_size=3, padding='same'),
    Conv2D(anchors[1] * 4, kernel_size=3, padding='same'),
    Conv2D(anchors[2] * 4, kernel_size=3, padding='same'),
    Conv2D(anchors[3] * 4, kernel_size=3, padding='same'),
    Conv2D(anchors[4] * 4, kernel_size=3, padding='same'),
    Conv2D(anchors[5] * 4, kernel_size=3, padding='same'),
    Conv2D(anchors[6] * 4, kernel_size=1)
]

# %%
conf1 = conf_head_layers[0](pr1)
print(conf1.shape)
conf2 = conf_head_layers[0](pr2)
print(conf2.shape)
conf3 = conf_head_layers[0](pr3)
print(conf3.shape)
conf4 = conf_head_layers[0](pr4)
print(conf4.shape)
conf5 = conf_head_layers[0](pr5)
print(conf5.shape)
conf6 = conf_head_layers[0](pr6)
print(conf6.shape)
# Out:
# (None, 1, 1, 28)
# (None, 4, 4, 28)
# (None, 8, 8, 28)
# (None, 16, 16, 28)
# (None, 32, 32, 28)
# (None, 64, 64, 28)

# %%
loc1 = loc_head_layers[0](pr1)
print(conf1.shape)
loc2 = loc_head_layers[0](pr2)
print(conf2.shape)
loc3 = loc_head_layers[0](pr3)
print(conf3.shape)
loc4 = loc_head_layers[0](pr4)
print(conf4.shape)
loc5 = loc_head_layers[0](pr5)
print(conf5.shape)
loc6 = loc_head_layers[0](pr6)
print(conf6.shape)
# Out:
# (None, 1, 1, 28)
# (None, 4, 4, 28)
# (None, 8, 8, 28)
# (None, 16, 16, 28)
# (None, 32, 32, 28)
# (None, 64, 64, 28)
